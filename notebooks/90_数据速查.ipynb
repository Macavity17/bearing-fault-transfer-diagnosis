# %%
import pandas as pd
import numpy as np
import scipy.io

# %%
A = scipy.io.loadmat("../data/raw/target/A.mat")

# %%
A['A']
# Out:
# array([[-1.98621003],
#        [-1.93686554],
#        [ 2.17414707],
#        ...,
#        [-6.98598415],
#        [-7.24518289],
#        [ 0.16686379]])

# %%
df = pd.DataFrame()

# %%
for letter in 'ABCDEFGHIJKLMNOP':
    df[letter] = scipy.io.loadmat("../data/raw/target/"+letter+".mat")[letter].flatten()

# %%
df
# Out:
#                A         B           C          D          E         F  \
# 0      -1.986210  0.425091  -75.386634  -0.046960   6.660980  5.867827
# 1      -1.936866 -0.190874   24.004519   1.266136   0.631981  2.258110
# 2       2.174147 -0.466894   90.396966   0.708628 -12.343657  1.675088
# 3       3.872046 -1.815877  -39.294926   4.554974 -12.626126  0.918379
# 4       1.918173 -0.757494 -110.328559   2.970624  -8.871179  0.499512
# ...          ...       ...         ...        ...        ...       ...
# 255995  8.333797  2.060889   -4.138100  -3.803729   5.876235  4.690989
# 255996  4.267503  4.322044    2.807557  -2.391664   5.537412 -1.672767
# 255997 -6.985984  1.474222    1.678521  -2.804223 -10.598236 -1.546042
# 255998 -7.245183 -2.207409   -3.365831  -5.518170 -12.760562  4.788136
# 255999  0.166864 -0.862632    0.519627 -11.342362  -0.411683  1.619996
#
#                G          H          I          J          K         L  \
# ...

# %%
df.to_csv("../data/raw/target/目标域.csv", index=False)
